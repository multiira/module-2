# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Ирина, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# Ссылка на проект:
# https://github.com/multiira/module-2

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Важно убрать чувствительные данные (логины, пароли). Ниже  об этом описал
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Можно еще добавить информацию в readme.md, где указать ключевые моменты проекта. Или зафиксировать цели и полученные выводы.

# %%
# Установим библиотеки при необходимости
#!pip install sqlalchemy 
#!pip install psycopg2 
#!pip install phik
#!pip install scipy
#!pip install pandas matplotlib seaborn
#!pip install --upgrade scipy
# Загружаем библиотеку для расчёта коэффициента корреляции phi_k
#from phik import phik_matrix
# Устанавливаем phik
import sys
from IPython.utils import io

with io.capture_output() as captured:
    # !pip install phik

# Импортируем необходимые библиотеки:
import pandas as pd
from sqlalchemy import create_engine

# Загружаем библиотеки для визуализации данных
import matplotlib.pyplot as plt
import seaborn as sns

# Загружаем библиотеку для расчёта коэффициента корреляции phi_k
from phik import phik_matrix

# Загружаем библиотеку для работы с env
#!pip install python_dotenv
import os
import dotenv

dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши
#
# ## Цель и задачи
#
# **Цель:** Провести исследовательский анализ данных пользователей Яндекс Афиши, чтобы понять, какие пользователи с большей вероятностью возвращаются на платформу и делают заказы повторно.
#
# **Задачи:**
# 1. Загрузить данные и познакомиться с их содержимым.
# 2. Провести предобработку данных.
# 3. Провести исследовательский анализ данных:
#     - изучить данные более детально;
#     - изучить взаимосвязь данных.
# 4. Сформулировать выводы по проведённому анализу.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Здорово, что оставляешь вводную часть! Она помогает быстро понять цель, контекст и структуру работы, что будет удобно не только для тебя при возвращении к проекту спустя время, но и любому другому читателю (если, например, публикуешь в открытый доступ для портфолио). Воспринимаем эту тетрадку не просто как выполнение домашней работы на курсе, а как полноценный исследовательский проект.
#
# Как правило, в вводную часть включают название проекта, краткое описание цели, используемых данных (источники, объем, особенности), нюансы самого проекта (специфические условия, ограничения, предположения и т.д.). Иногда также сразу обозначают план шагов. Другими словами, вводная часть призвана отразить, что мы делаем, с чем работаем и на каких условиях.
# </div>

# %% [markdown]
# ## Данные
#
# Для анализа используем данные из выборки, полученной запросом SQL из схемы `afisha`.
#
# Данные содержат информацию о заказах билетов клиентами сервиса за период июнь - октябрь 2024г.
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ ( mobile — мобильные устройства, desktop — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные created_dt_msk );
# - `order_ts` — дата и время создания заказа (используйте данные created_ts_msk );
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.

# %% [markdown]
# ## Структура проекта
#
# 1. Загрузка данных и знакомство с ними.
# 2. Предобработка данных.
# 3. Создание профиля пользователя.
# 4. Исследовательский анализ данных.
# 5. Итоговые выводы.

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Все необходимые библиотеки стоит выгружать в начале проекта в одной ячейке кода. Чтобы сразу видеть, какие модули используются в проекте

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Убрала всю загрузку в верхний блок.</div>

# %%
# Формируем строку для подключения:
connection_string = os.getenv('CONNECTION_STRING')
# Out:
# 'postgresql://praktikum_student:Sdf4$2;d-d30pp@rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net:6432/data-analyst-afisha'

# %%
# строку с данными для подключения передаем функции create_engine()
engine = create_engine(connection_string)

# %%
# Передаем query запрос для выгрузки данных
query = '''
SELECT
  p.user_id,
  p.device_type_canonical,
  p.order_id,
  p.created_dt_msk AS order_dt,
  p.created_ts_msk AS order_ts,
  p.currency_code,
  p.revenue,
  p.tickets_count,
  EXTRACT (DAY FROM (p.created_dt_msk - LAG(p.created_dt_msk) OVER (PARTITION BY p.user_id ORDER BY p.created_dt_msk))) AS days_since_prev,
  e.event_id,
  e.event_name_code AS event_name,
  e.event_type_main,
  p.service_name,
  r.region_name,
  c.city_name
FROM 
  afisha.purchases AS p
LEFT JOIN 
  afisha.events AS e ON p.event_id = e.event_id
LEFT JOIN 
  afisha.city AS c ON e.city_id = c.city_id
LEFT JOIN 
  afisha.regions AS r ON c.region_id = r.region_id
WHERE p.device_type_canonical IN ('mobile','desktop') AND e.event_type_main NOT IN ('фильм')
ORDER BY p.user_id;
'''

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
# Сейчас ты явным образом прописываешь параметры подключения к БД. В таком виде выкладывать работу в публичный доступ небезопасно, кто-то сможет завладеть подключением, украсть или повредить данные.
#
# Чтобы засекретить подключение, необходимо сложить все параметры в `.env` файл (или другой конфигурационный файл вне Git) и указать его в `.gitignore`:
#
# ```python
# DB_NAME="..."
# DB_HOST="..."
# DB_PORT="..."
# DB_USER="..."
# DB_PASSWORD="..."
# ```
#
# В самом проекте мы можем обращаться к сохраненным параметрам, для этого нам потребуются библиотеки `dotenv`, чтобы загрузить переменные окружения, и `os`, чтобы обратиться к ним:
#
# ```python
# import os
# import dotenv
#
# load_dotenv() # автоматически ищет .env в текущей директории
#
# connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
#     os.getenv('DB_USER'),
#     os.getenv('DB_PASSWORD'),
#     os.getenv('DB_HOST'),
#     os.getenv('DB_PORT'),
#     os.getenv('DB_NAME'),
# )
# ```
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# На гитхабе так нужно организовать обязательно, для принятия проекта.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Спрятала строку подключения в env файл.</div>

# %%
# Результат выдачи SQL запроса записываем в df:
df = pd.read_sql_query(query, con=engine)
# Зафиксируем изначальное количество строк 
initial_row_count = df.shape[0]

# %%
# Выводим первые строки датафрейма на экран
df.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name event_type_main  \
# ...

# %%
# Проверяем загруженные данные:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# - В датасете 15 столбцов и 290 611 строк.
# - В целом данные корректно выгрузились. Содержимое соответствует описанию.
# - Пустые значения только в расчетном столбце `days_since_prev`, где допускаются пустые значения в случае первого заказа клиента.
# - Можно оптимизировать разрядность для столбцов `order_id`, `tickets_count`, `event_id`, `revenue` и поменять тип данных для столбцов `days_since_prev` на Int.
# - Значения в столбцах `device_type_canonical`, `currency_code`, `event_type_main` представленые типом object можно оптимизировать, использовав категориальный тип.
# ___

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верно подмечено по поводу пропусков в поле `days_since_prev` (выше пишешь ` может быть всего 1 заказ`), их появление логично объясняется тем, что для некоторых пользователей это их первый заказ, и, соответственно, предыдущей даты для расчёта интервала просто нет.

# %% [markdown]
# ## 2. Предобработка данных

# %% [markdown]
# ### 2.1 Добавление столбца `revenue_rub`
# Данные в выручке представлены в двух валютах. Выгрузим курс валют и добавим столбец с выручкой в рублях.

# %%
# Загружаем данные:
df_rate = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')

# %% [markdown]
# Проверим данные в датасете с курсами:

# %%
# Проверим данные:
df_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    object
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.3+ KB

# %%
df_rate.head()
# Out:
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %% [markdown]
# Данные содержат информацию о курсе рубля за 100 тенге. Сразу подгрузить данные нельзя, так как даты в текстовом формате.
# - Преобразуем тип элементов столбца `data` в тип datetime.
# - Проверим на уникальность `data`
# - Добавим данные по курсам в датафрейм df столбцы дат
# - Вычислим выручку в рублях

# %%
# Преобразуем тип данных в столбце data
df_rate['data']=pd.to_datetime(df_rate['data'],format='%Y-%m-%d')

# Дополнительно оптимизируем данные в столбцах nominal и curs
df_rate['nominal'] = pd.to_numeric(df_rate['nominal'],downcast='integer')
df_rate['curs'] = pd.to_numeric(df_rate['curs'],downcast='float')

# %%
# Проверяем дубликаты по полю data
df_rate['data'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет. Можем добавлять данные.

# %%
df=df.merge(df_rate[['data','nominal','curs']], how='left', left_on='order_dt', right_on='data')

# %%
# Добавляем столбец revenue_rub
#df['revenue_rub'] = df['currency_code'].apply(lambda x: df['revenue'] if x=='rub' else df['revenue']/df['nominal']*df['curs'] )
#mask = df['currency_code'] == 'rub'
#df['revenue_rub'] = df['revenue'].copy()
#df.loc[~mask, 'revenue_rub'] = df.loc[~mask, 'revenue'] / df.loc[~mask, 'nominal'] * df.loc[~mask, 'curs']
df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / df['nominal'])

# %%
# удаляем лишние столбцы
df = df.drop(['data','nominal','curs'], axis=1)

# %%
# Проверяем, что получилось
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# Данные о выручке преобразованы к единой валюте и их можно использовать для анализа.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * При подгрузке любых данных тоит сперва убедиться, что они корректны, данные о курсе не исключение. Тогда бы мы как раз могли обосновать, что требуется корректировка типа данных для даты. Сейчас по сути этот шаг берется из ниоткуда.
#
#
# * Существует довольно удобный метод [where](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html). Мы можем применить его к столбцу и указать условие, которое будем проверять, а также альтернативный вариант значения. Если условие выполняется, то берется значение из столбца, если нет - альтернативное значение. Тогда расчет выручки в рублях будет выглядеть следующим образом:
#
#     ```python
# df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / 100)
# ```
#
#
# * Не забываем фиксировать в выводах наши промежуточные наблюдения (например, что все прошло хорошо, теперь выручка скорректирована, и ее можно использовать для дальнейшего анализа).
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> У меня была сделана проверка датафрейма с курсами - в начале этого блока вывела методом info() информацию о типах и методом head() проверила первые строки датафрейма с курсами. И после этого преобразовала даты к типу данных Data.
#
# Для дольшей логики:
# - Добавила ячейки Markdown перед выводом информации о датафрейме с курсами с описанием и после проверки информацию о несоответствии типа.
# - Поправила вычисление с помощью метода where.
# - Дописала вывод.</div>

# %% [markdown]
# ### 2.2 Предобработка
#
#  - проведем оптимизацию типов данных,
#  - проверим явные и неявные дубликаты,
#  - проверим значения-индикаторы,
#  - проверим числовые данные на предмет аномальных значений и выбросов.

# %% [markdown]
# - Оптимизируем типы

# %%
# Оптимизируем разрядность
df['order_id'] = pd.to_numeric(df['order_id'],downcast='integer')
df['tickets_count'] = pd.to_numeric(df['tickets_count'],downcast='integer')
df['event_id'] = pd.to_numeric(df['event_id'],downcast='integer')
df['revenue'] = pd.to_numeric(df['revenue'],downcast='float')
df['revenue_rub'] = pd.to_numeric(df['revenue_rub'],downcast='float')
# Поменяем тип на Int
df['days_since_prev'] = df['days_since_prev'].astype('Int16')
# Преобразуем два категориальных столбцы к category
df[['device_type_canonical', 'currency_code','event_type_main']] = df[['device_type_canonical', 'currency_code','event_type_main']].astype('category')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Ты молодец, что подумаа про оптимизацию памята, это полезная штука, особенно если работаешь с большими датасетами

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  category
#  2   order_id               290611 non-null  int32
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  category
#  6   revenue                290611 non-null  float32
#  7   tickets_count          290611 non-null  int8
#  8   days_since_prev        268678 non-null  Int16
#  9   event_id               290611 non-null  int32
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  category
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# - Проверим дубликаты

# %% [markdown]
# Явные дубликаты должны отсутствовать - делалась проверка данных в SQL.<br>
# Убедимся:

# %%
# Проверяем полные дубликаты
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Проверим неявные дубликаты - заказы от одного пользователя в одно и то же время на одну сумму:

# %%
# Проверим есть ли дубликаты по полям name+address
df.duplicated(subset=['user_id', 'order_ts', 'currency_code', 'revenue', 'tickets_count', 'event_id']).sum()
# Out:
# 44

# %% [markdown]
# Посмотрим, на эти строки:

# %%
# Находим дубликаты по нужным полям 
duplicates = df[df.duplicated(subset=['user_id', 'order_ts', 'currency_code', 'revenue', 'tickets_count', 'event_id'], keep=False)]

# Сортируем найденные дубликаты по полю name
duplicates_sorted = duplicates.sort_values(by=['user_id', 'order_ts'])

# Выводим отсортированные дубликаты
display(duplicates_sorted.head(10))
# Out:
#                user_id device_type_canonical  order_id   order_dt  \
# 11758  06eb7897f65b433                mobile   1123983 2024-08-13
# 11759  06eb7897f65b433                mobile   1123867 2024-08-13
# 12677  08199117318954f               desktop   5592970 2024-07-31
# 12678  08199117318954f                mobile   5593202 2024-07-31
# 26868  0dc525d7bacbb0d               desktop   1930763 2024-07-31
# 26869  0dc525d7bacbb0d               desktop   1930705 2024-07-31
# 51539  1f49b8de206b285                mobile   2968673 2024-10-01
# 51588  1f49b8de206b285               desktop   5378312 2024-10-01
# 53681  206ea45ec11d478                mobile   1935113 2024-10-29
# 53682  206ea45ec11d478                mobile   1935171 2024-10-29
#
#                  order_ts currency_code      revenue  tickets_count  \
# 11758 2024-08-13 16:31:07           rub    69.820000              1
# 11759 2024-08-13 16:31:07           rub    69.820000              1
# ...

# %% [markdown]
# Похоже на сбой при оформлении заказа. Дубликатов не много, относительно всего набора данных. Но удалим для "чистоты" данных.

# %%
# Оставим последнее вхождение, остальные дубликаты удалим
df.drop_duplicates(subset=['user_id', 'order_ts', 'currency_code', 'revenue', 'tickets_count', 'event_id'], keep='last', inplace=True)

# %% [markdown]
# - Проверим значения индикаторы. <br>
# Проверка данных к категориальных столбцах на предмет значений - индикаторов была выполнена в SQL.<br>
# Убедимся:

# %%
# Проверяем уникальные значения в столбцах на предмет индикаторов
for column in ['device_type_canonical', 'currency_code', 'event_type_main', 'service_name']:
    print(f'Уникальные значения в столбце {column}:')
    print(df[column].sort_values().unique())
    print()
# Out:
# Уникальные значения в столбце device_type_canonical:
# ['desktop', 'mobile']
# Categories (2, object): ['desktop', 'mobile']
#
# Уникальные значения в столбце currency_code:
# ['kzt', 'rub']
# Categories (2, object): ['kzt', 'rub']
#
# Уникальные значения в столбце event_type_main:
# ['выставки', 'другое', 'концерты', 'спорт', 'стендап', 'театр', 'ёлки']
# Categories (7, object): ['выставки', 'другое', 'концерты', 'спорт', 'стендап', 'театр', 'ёлки']
#
# Уникальные значения в столбце service_name:
# ['Crazy ticket!' 'Show_ticket' 'Билет по телефону' 'Билеты без проблем'
#  'Билеты в интернете' 'Билеты в руки' 'Быстробилет' 'Быстрый кассир'
#  'Весь в билетах' 'Восьмёрка' 'Вперёд!' 'Выступления.ру'
#  'Городской дом культуры' 'Дом культуры' 'Дырокол' 'За билетом!'
#  'Зе Бест!' 'КарандашРУ' 'Кино билет' 'Край билетов' 'Лимоны'
#  'Лови билет!' 'Лучшие билеты' 'Мир касс' 'Мой билет' 'Облачко'
#  'Прачечная' 'Радио ticket' 'Реестр' 'Росбилет' 'Тебе билет!' 'Телебилет'
# ...

# %% [markdown]
# - Проверим распределение данных в основных числовых столбцах

# %% [markdown]
# Сначала проверим `revenue_rub`

# %%
print(df['revenue_rub'].describe())
# Out:
# count    290567.000000
# mean        555.592346
# std         875.533081
# min         -90.760002
# 25%         113.970001
# 50%         351.140015
# 75%         802.049988
# max       81174.539062
# Name: revenue_rub, dtype: float64

# %% [markdown]
# Медиана 351 значительно ниже среднего 556. Стандартное отклонение высокое, высокий максимум и отрицательный минимум.<br>
# Предполагаем ассимитричное правостороннее распределение с выбросами в правой части.

# %% [markdown]
# Проверим отрицательные и нулевые значения. Это могут быть например возвраты ранее купленых билетов и бесплатные билеты:

# %%
# Проверяем отрицательные
print(f'Количество отрицательных заказов: {df[(df["revenue_rub"]<0)]["user_id"].count()}')
display(df[(df['revenue_rub']<0)].head())
# Out:
# Количество отрицательных заказов: 381
#               user_id device_type_canonical  order_id   order_dt  \
# 252   00eb3dc9baa1543                mobile   1594653 2024-06-29
# 4522  02ea4583333f064                mobile   2360920 2024-09-03
# 4549  02ea4583333f064                mobile   2361094 2024-09-04
# 8133  043f669c9f734b1                mobile    166809 2024-09-27
# 8134  043f669c9f734b1                mobile    166780 2024-09-27
#
#                 order_ts currency_code  revenue  tickets_count  \
# 252  2024-06-29 15:01:43           rub    -2.37              3
# 4522 2024-09-03 18:12:58           rub    -0.23              3
# 4549 2024-09-04 09:34:53           rub    -0.15              2
# 8133 2024-09-27 10:56:35           rub    -0.62              1
# 8134 2024-09-27 10:00:09           rub    -1.86              3
#
#       days_since_prev  event_id                            event_name  \
# 252              <NA>    538650  ffe03bc6-0e0c-480d-b037-6a4b55540ab5
# ...

# %% [markdown]
# На возвраты билетов не похоже. Отфильтруем эти значения.

# %%
# Отфильтруем строки с заказами с отрицательной выручкой
df = df[(df["revenue_rub"]>=0)]

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# Отлично, отрицательные значения изучены

# %% [markdown]
# Проверим нулевые значения

# %%
# Проверяем нулевые
print(f'Количество нулевых заказов: {df[(df["revenue_rub"]==0)]["user_id"].count()}')
display(df[(df['revenue_rub']==0)].head())
# Out:
# Количество нулевых заказов: 5524
#             user_id device_type_canonical  order_id   order_dt  \
# 24  0018ecd8a38a51b                mobile   3253250 2024-07-25
# 65  0033403583a55ed                mobile   4130500 2024-06-19
# 66  0033403583a55ed                mobile   4130529 2024-06-19
# 67  0033403583a55ed                mobile   4130442 2024-06-19
# 68  0033403583a55ed                mobile   4130471 2024-06-19
#
#               order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 24 2024-07-25 20:38:57           rub      0.0              3             <NA>
# 65 2024-06-19 11:07:15           rub      0.0              1             <NA>
# 66 2024-06-19 10:53:29           rub      0.0              1                0
# 67 2024-06-19 14:57:25           rub      0.0              1                0
# 68 2024-06-19 11:06:10           rub      0.0              1                0
#
#     event_id                            event_name event_type_main  \
# ...

# %% [markdown]
# Предположительно это могут быть бесплатные билеты. Эти данные оставим.

# %%
# Проверим распределение данных в revenue_rub
# Построим диаграмму размаха
boxplot = df.boxplot(column='revenue_rub', grid=False,vert=False, figsize=(12, 6))

# Добавляем заголовок и метки оси
boxplot.set_title('Распределение выручки в рублях по заказам')
boxplot.set_xlabel('Выручка')

plt.show()

# %% [markdown]
# Видим значительное число выбросов. Посмотрим на Диаграмму без выбросов:

# %%
# Проверим распределение данных в revenue_rub
# Построим диаграмму размаха
boxplot = df.boxplot(column='revenue_rub', grid=False, vert=False, figsize=(12, 6), showfliers=False)

# Добавляем заголовок и метки оси
boxplot.set_title('Распределение выручки в рублях по заказам')
boxplot.set_xlabel('Выручка')

plt.show()

# %%
# Посчитаем 99 перцентиль
outliers = df['revenue_rub'].quantile(0.99)

# %%
print(outliers)
# Out:
# 2628.421630859375

# %%
# Посчиаем количество строк для удачения
df.loc[df['revenue_rub'] >= outliers].shape[0]
# Out:
# 3007

# %%
# отфильтруем данные по 99 перцентилю по выручке, для тсключения выбросов и получения более достоверной статистики
df = df.loc[df['revenue_rub'] < outliers]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 287179 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                287179 non-null  object
#  1   device_type_canonical  287179 non-null  category
#  2   order_id               287179 non-null  int32
#  3   order_dt               287179 non-null  datetime64[ns]
#  4   order_ts               287179 non-null  datetime64[ns]
#  5   currency_code          287179 non-null  category
#  6   revenue                287179 non-null  float32
#  7   tickets_count          287179 non-null  int8
#  8   days_since_prev        265496 non-null  Int16
#  9   event_id               287179 non-null  int32
#  10  event_name             287179 non-null  object
#  11  event_type_main        287179 non-null  category
#  12  service_name           287179 non-null  object
#  13  region_name            287179 non-null  object
# ...

# %% [markdown]
# Проверим `tickets_count`

# %%
# Проверяем распределение данных по значениям столбца tickets_count
print('Распределение данных по значениям столбца tickets_count:')
df['tickets_count'].value_counts()
# Out:
# Распределение данных по значениям столбца tickets_count:
# 3     91407
# 2     83523
# 4     53621
# 1     41655
# 5     12850
# 6      3943
# 7        58
# 9        38
# 10       19
# 8        18
# 11       13
# 13        7
# 17        6
# 19        5
# 14        4
# 12        3
# 15        2
# 27        2
# 30        2
# 37        1
# 47        1
# 57        1
# Name: tickets_count, dtype: int64

# %% [markdown]
# Распределение данных по числу билетов в заказе выглядит логичным. <br>
# Есть некоторое количество выбросов справа.

# %%
print(df['tickets_count'].describe())
# Out:
# count    287179.000000
# mean          2.741161
# std           1.163420
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %%
# Проверим распределение данных в tickets_count
# Построим диаграмму размаха
boxplot = df.boxplot(column='tickets_count', grid=False, vert=False, figsize=(12, 6), showfliers=True)

# Добавляем заголовок и метки оси
boxplot.set_title('Распределение количества билетов по заказам')
boxplot.set_xlabel('Число билетов в заказе')

plt.show()

# %% [markdown]
# Основные статистики и диаграмма размаха подтверждают выводы, сделанные выше. Данные отфильтровывать не будем - они помогут нам в подготовке профиля пользователя.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 287179 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                287179 non-null  object
#  1   device_type_canonical  287179 non-null  category
#  2   order_id               287179 non-null  int32
#  3   order_dt               287179 non-null  datetime64[ns]
#  4   order_ts               287179 non-null  datetime64[ns]
#  5   currency_code          287179 non-null  category
#  6   revenue                287179 non-null  float32
#  7   tickets_count          287179 non-null  int8
#  8   days_since_prev        265496 non-null  Int16
#  9   event_id               287179 non-null  int32
#  10  event_name             287179 non-null  object
#  11  event_type_main        287179 non-null  category
#  12  service_name           287179 non-null  object
#  13  region_name            287179 non-null  object
# ...

# %% [markdown]
# #### Промежуточные выводы после предобработки
#
# Проведена предобработка данных:
# - Добавлен столбец `revenue_rub`- приведены данные из столбца `revenue` к единой валюте.
# - Оптимизированы типы данных
#     - `device_type_canonical`, `currency_code` и `event_type_main` приведены к типу `category`
#     - `revenue`, `revenue_rub` - оптимизирован к размерности `float32`
#     - `order_id` и `event_id` оптимизирован до размерности `int32`, `tickets_count` - оптимизирован к размерности `int8`, `days_since_prev` приведен к типу `Int16`- оставлены пропуски.
# - Пустые значения только в расчетном столбце `days_since_prev`, где допускаются пустые значения в случае первого заказа клиента.
# - Данные проверили на явные и неявные дубликаты — удалено 44 неявных дубликата.
# - В столбце `revenue_rub` найдено 381 отрицательных значений, которые были удалены.
# - Удалено 3007 строк по 99 перцентилю в столбце `revenue_rub`.

# %%
print(f'Всего удалено {initial_row_count-df.shape[0]} строки, что составляет {round((initial_row_count-df.shape[0])/initial_row_count,4)*100}%.')
# Out:
# Всего удалено 3432 строки, что составляет 1.18%.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# * В целом с задачей справились, предобработку провели!
#
#
# * Хорошо, что сопровождаешь графики заголовком и всеми необходимыми подписями - сразу понятно, что изображено на нем и как его читать!

# %% [markdown]
# ___

# %% [markdown]
# ## 3. Создание профиля пользователя

# %% [markdown]
# ### 3.1. Построение профиля пользователя
# Для каждого пользователя найдем:
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле event_type_main );
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами. <br>
#
# Добавим два бинарных признака:
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.

# %% [markdown]
# Отсортируем данные по времени совершения заказа и затем соберем сгруппированный датафрейм с нужными полями.

# %%
# Проведем агрегацию по user_id с добавлением необходимых полей.
user_profile = (df
          # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
          .sort_values(by='order_ts')
          # Затем группируем по номеру пользователя и агрегируем данные:
          .groupby('user_id')
          .agg(
              # Находим первую и последнюю даты заказа:
              first_date=('order_dt','min'),
              last_date=('order_dt','max'),
              # Находим устройства, регион, название билетного партнера и тип мероприятия первого заказа:
              first_device=('device_type_canonical','first'),
              first_region=('region_name','first'),
              first_service=('service_name','first'),
              first_event_type=('event_type_main','first'),
              # Подсчитваем количество заказов:
              total_orders=('order_id','nunique'),
              # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
              avg_revenue=('revenue_rub','mean'),
              avg_tickets=('tickets_count','mean'),
              # Считаем среднее количество дней между покупками:
              avg_days=('days_since_prev','mean')
          )
          # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
          .assign(
              is_two = lambda x: (x['total_orders'] >= 2).astype(int),
              is_five = lambda x: (x['total_orders'] >= 5).astype(int)
          )
          .reset_index()
  )

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Также есть довольно удобный метод [assign](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html), позволяющий дополнять таблицу новыми рассчитанными столбцами.
#
#     Тогда создание всего профиля можно будет записать красивым и удобным по структуре кодом.
#
#     <details> <summary> <span style='color:blue' > Развернуть подробнее. </span> </summary>
#
#     ```python
#     profiles = (df
#             # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
#             .sort_values(by='order_ts')
#             # Затем группируем по номеру пользователя и агрегируем данные:
#             .groupby('user_id')
#             .agg(
#                 # Находим первую и последнюю даты заказа:
#                 first_order_dt=('order_dt','min'),
#                 last_order_dt=('order_dt','max'),
#                 # Находим устройства, регион, название билетного партнера и тип мероприятия первого заказа:
#                 first_device=('device_type_canonical','first'),
#                 first_region_name=('region_name','first'),
#                 first_service_name=('service_name','first'),
#                 first_event_type=('event_type_main','first'),
#                 # Подсчитваем количество заказов:
#                 total_orders=('order_id','nunique'),
#                 # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
#                 avg_revenue_rub=('revenue_rub','mean'),
#                 avg_tickets_count=('tickets_count','mean'),
#                 # Считаем среднее количество дней между покупками:
#                 avg_days_since_prev=('days_since_prev','mean')
#             )
#             # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
#             .assign(
#                 is_two = lambda x: x['total_orders'] >= 2,
#                 is_five = lambda x: x['total_orders'] >= 5
#             )
#             .reset_index()
#     )
#     ```
#     </details>
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Поправила код, спасибо!</div>

# %% [markdown]
# ### 3.2 Проверка данных: насколько они репрезентативны и нет ли в них аномалий
# Используя данные о профилях пользователей, рассчитаем:
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.<br>
#
# Также изучим статистические показатели:
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками

# %% [markdown]
# #### 3.2.1 Рассчитаем необходимые показатели

# %%
user_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21832 entries, 0 to 21831
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           21832 non-null  object
#  1   first_date        21832 non-null  datetime64[ns]
#  2   last_date         21832 non-null  datetime64[ns]
#  3   first_device      21832 non-null  object
#  4   first_region      21832 non-null  object
#  5   first_service     21832 non-null  object
#  6   first_event_type  21832 non-null  object
#  7   total_orders      21832 non-null  int64
#  8   avg_revenue       21832 non-null  float32
#  9   avg_tickets       21832 non-null  float64
#  10  avg_days          13501 non-null  Float64
#  11  is_two            21832 non-null  int64
#  12  is_five           21832 non-null  int64
# dtypes: Float64(1), datetime64[ns](2), float32(1), float64(1), int64(3), object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# Новый датасет содержит чуть менее 22 тыс строк и 13 столбцов. Пропуски ожидаемо только в одном столбце.

# %%
print(f'Общее число пользователей в выборке: {user_profile.shape[0]}')
# Out:
# Общее число пользователей в выборке: 21832

# %%
print(f'Средняя выручка с одного заказа: {round(user_profile["avg_revenue"].mean(),0)}')
# Out:
# Средняя выручка с одного заказа: 544.0

# %%
print(f'Доля пользователей, совершивших 2 и более заказа: {round(user_profile["is_two"].mean(),2)}')
# Out:
# Доля пользователей, совершивших 2 и более заказа: 0.62

# %%
print(f'Доля пользователей, совершивших 5 и более заказов: {round(user_profile["is_five"].mean(),2)}')
# Out:
# Доля пользователей, совершивших 5 и более заказов: 0.29

# %% [markdown]
# #### 3.2.2 Изучим статистические показатели:

# %% [markdown]
# - средняя выручка:

# %%
# Проверим среднюю выручку
user_profile['avg_revenue'].describe()
# Out:
# count    21832.000000
# mean       544.015137
# std        429.635651
# min          0.000000
# 25%        213.695522
# 50%        467.532089
# 75%        763.766525
# max       2624.814453
# Name: avg_revenue, dtype: float64

# %% [markdown]
# Судя по всему правсторонее ассиметричное распределение с выбросами справа.<br>
# Нулевые данные были оставлены при предобработке данных - возможны бесплатные билеты.<br>
# Данные выглядят логично.

# %% [markdown]
# - общее число заказов

# %%
# Проверим кол-во заказов
user_profile['total_orders'].describe()
# Out:
# count    21832.000000
# mean        13.154040
# std        121.512117
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      10162.000000
# Name: total_orders, dtype: float64

# %% [markdown]
# Максимальное число заказов выглядит немного странно.

# %%
# Построим дополнительно диаграмму размаха
boxplot = user_profile.boxplot(column='total_orders', grid=False, vert=False, figsize=(12, 6), showfliers=True)

# Добавляем заголовок и метки оси
boxplot.set_title('Распределение общего кол-ва заказов')
boxplot.set_xlabel('Общее количество заказов')

plt.show()

# %% [markdown]
# Аномально высокое значение не единственное. Это могут быть как ошибки с данными так и агрегаторы (или id-агрегаторы), которые не интересны при анализе.
#
# Посчитаем 95 и 99 перцентиль.

# %%
outliers_95 = user_profile['total_orders'].quantile(0.95)
outliers_99 = user_profile['total_orders'].quantile(0.99)

print(f'95й перцентиль = {outliers_95}')
print(f'99й перцентиль = {outliers_99}')
# Out:
# 95й перцентиль = 31.0
# 99й перцентиль = 152.0

# %% [markdown]
# 95й перцентиль выглядит более правдоподобно. Отфильтруем данные:

# %%
# отфильтруем данные по 95 перцентилю по числу заказов, для исключения выбросов и получения более достоверной статистики
user_profile = user_profile.loc[user_profile['total_orders'] < outliers_95]

# %% [markdown]
# - среднее число билетов в заказе:

# %%
# Проверим среднее число билетов в заказе
user_profile['avg_tickets'].describe()
# Out:
# count    20712.000000
# mean         2.744462
# std          0.935373
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.166667
# max         11.000000
# Name: avg_tickets, dtype: float64

# %%
# Дополнительно посмотрим на моду
print(user_profile['avg_tickets'].mode())
# Out:
# 0    3.0
# dtype: float64

# %% [markdown]
# Среднее значение соответствует медиане, что говорит о симметричном распределении.<br>
# Судя по максимуму - выбросы есть, но их не много.<br>
# Данные выглядят корректно.

# %% [markdown]
# - среднее количество дней между покупками:

# %% [markdown]
# Проверим количество пользователей с одним заказом и `avg_days` = 0. Такие данные могли возникнуть из-за фильтрации. Если таких данных много - обработаем их.

# %%
user_profile[(user_profile['avg_days']==0)&(user_profile['total_orders']==1)].shape[0]
# Out:
# 9

# %% [markdown]
# Данных не много, влияния на результат не окажут. Не трогаем.

# %%
# Проверим статистики по среднему количеству дней между покупками
user_profile['avg_days'].describe()
# Out:
# count    12381.000000
# mean        17.112776
# std         22.932977
# min          0.000000
# 25%          1.000000
# 50%          9.500000
# 75%         22.250000
# max        148.000000
# Name: avg_days, dtype: float64

# %% [markdown]
# Поле содержит пропуски по пользователям с одним заказом в изначальном датафрейме. <br>
# Среднее значительно больше медианы - большое число выбросов справа. <br>
# Необычно, что не меньше четверти пользователей имеют среднее кол-во дней между заказами 1. Это может говорить о докупке дополнительного билета.

# %%
# Построим дополнительно диаграмму размаха
boxplot = user_profile.boxplot(column='avg_days', grid=False, vert=False, figsize=(12, 6), showfliers=True)

# Добавляем заголовок и метки оси
boxplot.set_title('Распределение среднего количества дней между заказами')
boxplot.set_xlabel('Среднее кол-во дней')

plt.show()

# %% [markdown]
# Выбросов действительно много. Но их значения вполне корректны. И это клиенты, которые пришли повторно. Если мы их отфильтруем - можем получить искажение данных о поведении лояльных клиентов. Не удаляем.

# %% [markdown]
# ### 3.3 Промежуточные итоги
# Агрегированные показатели и данные:

# %%
# Пересчитаем показатели после очистки данных
print(f'Общее число пользователей в выборке: {user_profile.shape[0]}')
print(f'Средняя выручка с одного заказа: {round(user_profile["avg_revenue"].mean(),0)}')
print(f'Доля пользователей, совершивших 2 и более заказа: {round(user_profile["is_two"].mean(),2)}')
print(f'Доля пользователей, совершивших 5 и более заказов: {round(user_profile["is_five"].mean(),2)}')
# Out:
# Общее число пользователей в выборке: 20712
# Средняя выручка с одного заказа: 546.0
# Доля пользователей, совершивших 2 и более заказа: 0.6
# Доля пользователей, совершивших 5 и более заказов: 0.25

# %% [markdown]
# Было удалено 1120 строк (5% объема данных) по полю `total_orders`.
# В остальном данные выглядят логично.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Здесь  все супер, выполнены все необходимые шаги!
#
#
# Как рекомендация, было бы не лишним также проверить, насколько изменилась средняя выручка после удаления выбросов. Посмотреть на распределение данных с помощью гистограмм и диаграмм размаха.
#
#
# Так же, хорошо было бы лучше сначала обосновать выбор стратегии по обработке, а потом уже приступить к ее выполнению при необходимости.

# %% [markdown]
# ## 4. Исследовательский анализ данных
# Исследуем признаки, влияющих на возврат пользователей, на совершение повторного заказа.

# %% [markdown]
# ### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
# Исследуем признаки, описывающие первый заказ пользователя, и оценим их влияние на вероятность возвращения пользователя.

# %% [markdown]
# #### 4.1.1. Распределение пользователей по признакам.
# - Сгруппируем пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
#
# - Подсчитаем общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака.

# %%
# Вычисляем для типа первого мероприятия в заказе
# Получаем абсолютные значения
absolute_counts = user_profile['first_event_type'].value_counts()

# Вычисляем относительные значения
relative_counts = user_profile['first_event_type'].value_counts(normalize=True).round(3)

# Объединяем результаты в один датафрейм
result = pd.DataFrame({'user_num': absolute_counts, 'share_user_num': relative_counts})
print('\nРаспределение пользователей по типу мероприятия:')
print(result)
# Out:
# Распределение пользователей по типу мероприятия:
#           user_num  share_user_num
# концерты      9167           0.443
# другое        5153           0.249
# театр         4065           0.196
# стендап       1069           0.052
# спорт          763           0.037
# выставки       401           0.019
# ёлки            94           0.005

# %%
# Вычисляем для устройства, с которого сделан первый заказ
# Получаем абсолютные значения
absolute_counts = user_profile['first_device'].value_counts()

# Вычисляем относительные значения
relative_counts = user_profile['first_device'].value_counts(normalize=True).round(3)

# Объединяем результаты в один датафрейм
result = pd.DataFrame({'user_num': absolute_counts, 'share_user_num': relative_counts})
print('\nРаспределение пользователей по типу устройства:')
print(result)
# Out:
# Распределение пользователей по типу устройства:
#          user_num  share_user_num
# mobile      17181            0.83
# desktop      3531            0.17

# %%
# Вычисляем для региона, из которого сделан первый заказ
# Получаем абсолютные значения
absolute_counts = user_profile['first_region'].value_counts()

# Вычисляем относительные значения
relative_counts = user_profile['first_region'].value_counts(normalize=True).round(3)

# Объединяем результаты в один датафрейм
result = pd.DataFrame({'user_num': absolute_counts, 'share_user_num': relative_counts})
print('\nРаспределение пользователей по региону мероприятия топ-10:')
print(result.head(10))
# Out:
# Распределение пользователей по региону мероприятия топ-10:
#                       user_num  share_user_num
# Каменевский регион        6775           0.327
# Североярская область      3597           0.174
# Широковская область       1181           0.057
# Озернинский край           659           0.032
# Малиновоярский округ       516           0.025
# Травяная область           468           0.023
# Шанырский регион           462           0.022
# Светополянский округ       436           0.021
# Речиновская область        421           0.020
# Яблоневская область        397           0.019

# %%
# Вычисляем для билетного сервиса, через который сделан первый заказ
# Получаем абсолютные значения
absolute_counts = user_profile['first_service'].value_counts()

# Вычисляем относительные значения
relative_counts = user_profile['first_service'].value_counts(normalize=True).round(3)

# Объединяем результаты в один датафрейм
result = pd.DataFrame({'user_num': absolute_counts, 'share_user_num': relative_counts})
print('\nРаспределение пользователей по билетному оператору топ-10:')
print(result.head(10))
# Out:
# Распределение пользователей по билетному оператору топ-10:
#                     user_num  share_user_num
# Билеты без проблем      4949           0.239
# Мой билет               2840           0.137
# Лови билет!             2703           0.131
# Билеты в руки           2420           0.117
# Облачко                 2107           0.102
# Весь в билетах          1232           0.059
# Лучшие билеты           1130           0.055
# Прачечная                549           0.027
# Край билетов             438           0.021
# Дом культуры             339           0.016

# %% [markdown]
# Основная доля пользователей первый заказ делает:
# - 44% на концерты, 25% на другие типы мероприятий и 20% в театры
# - 83% с мобильных телефонов и 17% с настольных компьютеров
# - 33% из Каменевского региона, 17% с Североярской области и 6% из Широковской обрасти
# - 24% с сервиса Билеты без проблем , 14% - Мой билет, 13% - Лови билет!, 12% - Билеты в руки и 10% - Облачко.
#
# Сегменты с наибольшим числом пользователей есть в разрезе всех рассмотренных признаках.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# По результатам всё верно
#
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * Визуализировать полученные данные,
#
# * По выводам хорошо бы показать общую картину: как распределяются пользователи по сегментам, какие группы преобладают, какие встречаются реже и почему так может быть. А уже после этого привести конкретные значения - как подтверждение своих наблюдений.

# %% [markdown]
# #### 4.1.2. Анализ возврата пользователей
# Для каждого сегмента вычислим долю пользователей, совершивших два и более заказа и построим стобчатые диаграммы для сравнения доли между сегментами.

# %%
# Построим график столбчатой диаграммы для типа мероприятия
grouped = user_profile.groupby('first_event_type')['is_two'].mean().sort_values(ascending=False)
ax=grouped.plot(kind='bar',
               title=f'Доля клиентов с повторными заказами в зависимости от мероприятия',
               legend=False,
               ylabel='Доля',
               xlabel='Тип мероприятия',
               rot=0,
               figsize=(10, 4))
# Добавляем значения над каждым столбцом
for i, v in enumerate(grouped):
    ax.text(i, v + 0.01, str(round(v, 2)), color='black', ha='center')
# Настраиваем отступы
ax.set_ylim(bottom=0, top=grouped.max()*1.1)
# Выводим график
plt.show()

# %% [markdown]
# - Доля клиентов, повторно совершивших заказ самая высокая у клиентов, купивших билеты на выставки - 63%. На втором и третьем месте самые популярны  категории театр и концерты.
# - Значительно ниже среднего 60% по всей выборке профилей доля повторных заказов у пользователей сделавший первоначальный заказ на спортивные мероприятия и елки по 54% и 55%.

# %%
# Построим график столбчатой диаграммы для типа устройства
grouped = user_profile.groupby('first_device')['is_two'].mean().sort_values(ascending=False)
ax=grouped.plot(kind='bar',
               title=f'Доля клиентов с повторными заказами по типу устройства',
               legend=False,
               ylabel='Доля',
               xlabel='Тип устройства',
               rot=0,
               figsize=(10, 4))
# Добавляем значения над каждым столбцом
for i, v in enumerate(grouped):
    ax.text(i, v + 0.01, str(round(v, 2)), color='black', ha='center')
# Настраиваем отступы
ax.set_ylim(bottom=0, top=grouped.max()*1.1)
# Выводим график
plt.show()

# %% [markdown]
# - Доля вернувшихся клиентов, сделавших первый заказ и через мобильный телефон 59% и через компьютер 62% близка к среднему 60%.

# %%
# Построим график столбчатой диаграммы для региона
# Зафиксируем топ-10 регионов по количеству клиентов
user_counts = user_profile['first_region'].value_counts().head(10)
grouped = user_profile.groupby('first_region')['is_two'].mean().loc[user_counts.index].sort_values(ascending=False)
ax=grouped.plot(kind='bar',
               title=f'Доля клиентов с повторными заказами по региону топ-10',
               legend=False,
               ylabel='Доля',
               xlabel='Регион',
               rot=90,
               figsize=(10, 4))
# Добавляем значения над каждым столбцом
for i, v in enumerate(grouped):
    ax.text(i, v + 0.01, str(round(v, 2)), color='black', ha='center')
# Настраиваем отступы
ax.set_ylim(bottom=0, top=grouped.max()*1.1)
# Выводим график
plt.show()

# %% [markdown]
# - По регионам доля колеблется от 65% по Шанырскому региону до 55% и 54% по Малиновоярскому округу и Озеринскому краю соответственно.
# - По самому популярному Каменевскому региону доля 61%, что близко к среднему значению 60% по всей выборке.

# %%
# Построим график столбчатой диаграммы для билетного сервиса
# Зафиксируем топ-10 билетных сервисов по количеству клиентов
user_counts = user_profile['first_service'].value_counts().head(10)
grouped = user_profile.groupby('first_service')['is_two'].mean().loc[user_counts.index].sort_values(ascending=False)
ax=grouped.plot(kind='bar',
               title=f'Доля клиентов с повторными заказами по билетному сервису',
               legend=False,
               ylabel='Доля',
               xlabel='Билетный сервис',
               rot=90,
               figsize=(10, 4))
# Добавляем значения над каждым столбцом
for i, v in enumerate(grouped):
    ax.text(i, v + 0.01, str(round(v, 2)), color='black', ha='center')
# Настраиваем отступы
ax.set_ylim(bottom=0, top=grouped.max()*1.1)
# Выводим график
plt.show()

# %% [markdown]
# - По билетному сервису небольшой разброс относительно среднего по всей выборке - от 64% до 59%.
# - Доля повторных заказов у клиентов сделавших первый заказ через топ-3 самых популярных сервисов самая низкая.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Опять же, было бы не лишним дать понятное название подразделу и добавить пояснение к шагу.
#
#
# * В случае вывода неполного набора сегментов стоит указать, какой процент от выборки они составляют, чтобы было понимание, насколько большая часть данных осталась за пределами нашего обзора.
#
#
#
#
# * Также было бы неплохо добавить на графики линию среднего значения, чтобы было удобно сравнивать, какие сегменты и насколько отличаются от общего показателя по выборке. Это можно сделать с помощью `plt.axvline`, потребуется также добавить легенду.
#
#
# </div>

# %% [markdown]
# #### 4.1.3. Проверка продуктовых гипотез

# %% [markdown]
# - Гипотеза 1. Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты. <br>
# Нет, это не так. Доля повторных заказов среди пользователей сделавших первый заказ на спортивное мероприятие всего 54%, а на концерты - 60%.
# - Гипотеза 2. В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.<br>
# В целом в трех самых популярных регионах доля повторных заказов выше среднего, но они не являются самыми высокими по доле.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# По второй гипотезе можно сопоставить объем выборки с полученными результатом

# %% [markdown]
# ### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа

# %% [markdown]
# #### 4.2.1. Cвязь между средней выручкой сервиса с заказа и повторными заказами.

# %%
plt.figure(figsize=(10, 4))

# Округляем значения столбеца avg_revenue
user_profile['avg_revenue'] = user_profile['avg_revenue'].round()

# Находим минимальное и максимальное значения
min_value = int(user_profile['avg_revenue'].min())
max_value = int(user_profile['avg_revenue'].max())

# Строим гистограммы для каждого значения is_two
for i in user_profile['is_two'].unique():
    # Фильтруем данные по значению столбца is_two
    user_profile.loc[user_profile['is_two'] == i, 'avg_revenue'].plot(
        kind='hist',
        density=True,
        bins=range(min_value, max_value+1, 50),
        alpha=0.5,
        label=f'{i}',
        legend=True
    )
# Настраиваем внешний вид графика и выводим его на экран
plt.title(f'Сравнение распределение средней выручки клиента в зависимости от признака "is_two"')
plt.xlabel('Средняя выручка')
plt.ylabel('Плотность вероятности')
plt.legend(title='is_two')
plt.show()

# %% [markdown]
# Распределение средней выручки у клиентов с повторными заказами значительно отличается от распределения у клиентов с одним заказом:
# - у клиентов с 1 заказом смещено влево к нулевым значениям и имеет длинный хвост справа. Максимум находится около нуля.
# - у клиентов с повторными заказами тоже имеет небольшое смещение влево, но при этом максимум находится около значения 500 руб.

# %% [markdown]
# #### 4.2.2. Cвязь между средней выручкой с заказа в сегменте клиентов с повторными заказами
# Рассмотрим подробнее сегмент с повторными заказами. Отдельно рассмотрим поведение клиентов с 5 и более заказами и менее 5 заказами.

# %%
plt.figure(figsize=(10, 4))

filtered_data=user_profile[user_profile['is_two']==1]
# Находим минимальное и максимальное значения
min_value = int(filtered_data['avg_revenue'].min())
max_value = int(filtered_data['avg_revenue'].max())

# Строим гистограммы для каждого значения is_two
for i in filtered_data['is_five'].unique():
    # Фильтруем данные по значению столбца is_two
    filtered_data.loc[filtered_data['is_five'] == i, 'avg_revenue'].plot(
        kind='hist',
        density=True,
        bins=range(min_value, max_value+1, 50),
        alpha=0.5,
        label=f'{i}',
        legend=True
    )
# Настраиваем внешний вид графика и выводим его на экран
plt.title(f'Сравнение распределение средней выручки клиента в зависимости от признака "is_five" ("is_two"==1)')
plt.xlabel('Средняя выручка')
plt.ylabel('Плотность вероятности')
plt.legend(title='is_five')
plt.show()

# %% [markdown]
# - Распределение клиентов с количеством повторных заказов от 2х до 4х  более пологое, чем клиентов с 1 заказом, но максимум так же в районе 0го значения выручки.
# - Максимум в районе значения выручки 500 за счет клиентов с 5ю заказами и выше.

# %% [markdown]
# Посчитаем статистические показатели по группам клиентов:

# %%
#Посчитаем статистические показатели по группам:
print('\nСтатистика по группе с 1 заказом:')
user_profile[user_profile['is_two']==0]['avg_revenue'].describe()
# Out:
# Статистика по группе с 1 заказом:
# count    8360.000000
# mean      544.697754
# std       517.164673
# min         0.000000
# 25%       133.000000
# 50%       378.500000
# 75%       828.250000
# max      2625.000000
# Name: avg_revenue, dtype: float64

# %%
print('\nСтатистика по группе с 2-4 заказами:')
user_profile[(user_profile['is_two']==1)&(user_profile['is_five']==0)]['avg_revenue'].describe()
# Out:
# Статистика по группе с 2-4 заказами:
# count    7144.000000
# mean      551.571106
# std       418.657990
# min         0.000000
# 25%       219.750000
# 50%       472.000000
# 75%       799.000000
# max      2625.000000
# Name: avg_revenue, dtype: float64

# %%
print('\nСтатистика по группе с 5 заказами и более:')
user_profile[(user_profile['is_two']==1)&(user_profile['is_five']==1)]['avg_revenue'].describe()
# Out:
# Статистика по группе с 5 заказами и более:
# count    5208.000000
# mean      542.304749
# std       312.364105
# min         0.000000
# 25%       318.000000
# 50%       515.000000
# 75%       728.000000
# max      2072.000000
# Name: avg_revenue, dtype: float64

# %% [markdown]
# Было рассмотрено 3 группы клиентов. Все три группы имеют схожий средний показатель по выручке, но есть значительная разница:
# - группа с 1 заказом (40% выборки) имеет высокое стандартное отклонение 517. Медиана 379 ниже среднего 544 - говорит о смещении распределения влево с большим объемом выбросов справа. 25% клиентов имеют в этой группе средний чек менее 133 рублей. <br>
# Такие значительные отклонения в группе могут быть связаны с однократной покупкой большого количества билетов для групп (детские сады, школы и тп.)- выбросы справа или переход по ссылкам для бронирования бесплатного билета или возврата билета - нулевые значения.
#
#
# - группа с 2-4 заказами (35% выборки) имеет стандартное отклонение 418 - распределение уже более плотно сконцентрировано относительно среднего. Медиана 472 начинает приближаться к среднему 552, но все еще ниже него.
#
#
# - группа с 5 и более заказами (25% выборки) медиана 515 уже сопоставима со среднем показателем 542, а стандартное отклонение сокращено до 312 - все данные более сконцентрированы около среднего.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Можно чуть структурировать интерпретацию. Начни с общего сравнения (чем отличаются группы в целом), затем подчеркни ключевые различия в диапазонах (например, что возвращающиеся чаще в зоне от...–до... ₽, а однократные имеют больший разброс), и завершай возможными причинами — например, что нулевая выручка у однократных, вероятно, связана с возвратами, а крупные заказы — с разовыми покупками для групп.
#
# Еще можно добавить расчёты медины и среднего, чтобы понимать - имеется ли смещение и в какую сторону

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавила расчет статистических показателей и постаралась структурировать выводы по группам.</div>

# %% [markdown]
# #### 4.2.3. Влияние среднего количества билетов в заказе на вероятность повторной покупки.

# %% [markdown]
# Изучим распределение пользователей по среднему количеству билетов.

# %%
plt.figure(figsize=(10, 4))

user_profile['avg_tickets'].plot(
        kind='hist',
        bins=11,
        #alpha=0.5,
        label=f'{i}',
        #legend=True
    )
# Настраиваем внешний вид графика и выводим его на экран
plt.title(f'Распределение среднего числа билетов в заказе')
plt.xlabel('Среднее число билетов')
plt.ylabel('Число клиентов')

plt.show()

# %% [markdown]
# Среденее число билетов в заказе сосредоточено в диапазоне от 1 до 4х.

# %%
# Дополнительно посмотрим основные статистики
user_profile['avg_tickets'].describe()
# Out:
# count    20712.000000
# mean         2.744462
# std          0.935373
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.166667
# max         11.000000
# Name: avg_tickets, dtype: float64

# %%
user_profile['avg_tickets'].mode()
# Out:
# 0    3.0
# dtype: float64

# %% [markdown]
# - Данные имеют незначительный разброс.
# - Среднее практически совпадает с медианой что может указывать на симметричное распределение.
# - Самое часто встречающееся среднее число билетов у пользователей = 3.

# %% [markdown]
# Разделим пользователей на несколько сегментов по среднему количеству билетов в заказе:

# %%
# Определяем интервалы
bins = [1, 2, 3, 5, float('inf')]
labels = ['<=2 билетов', '<= 3 билетов', '<= 5 билетов', '> 5 билетов']

# Разбиваем столбец на интервалы
user_profile['ticket_interval'] = pd.cut(user_profile['avg_tickets'], bins=bins, labels=labels)

# %%
# делаем группировку по столбцу с интервалом
result=user_profile.groupby('ticket_interval').agg(
    user_count = ('user_id', 'count'), # количество пользователей
    repurchase_rate = ('is_two', 'mean'), # доля клиентов совершивших два и более заказов
).reset_index()
result['repurchase_rate']=result['repurchase_rate'].round(2)
display(result)
# Out:
#   ticket_interval  user_count  repurchase_rate
# 0     <=2 билетов        4812             0.48
# 1    <= 3 билетов        9133             0.72
# 2    <= 5 билетов        5236             0.62
# 3     > 5 билетов         194             0.32

# %% [markdown]
# - наибольшее число клиентов в интервале с числом билетов (2;3] = 9133
# - доля клиентов с повторными заказами большего всего в этом же сегменте (2;3] = 0.72
# - наименьшая доля клиентов с повторными заказами 0.32 в сегменте `>5 билетов`, но в сегменте низкое число пользователей 194, и доля может быть недостоверной
# - в сегменте (1;2] билетов доля клиентов с повторными заказами так же низкая = 0.48

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно чуть развить вывод — предположить, почему пользователи, покупающие 2–3 билета, возвращаются чаще. Например, это могут быть небольшие компании или семьи, которые чаще ходят на мероприятия вместе, а значит, лояльность у них выше. А вот пользователи с 5+ билетами, вероятно, совершают разовые групповые покупки (например, для организации или класса), поэтому возвращаются реже

# %% [markdown]
# ### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
# Изучим временные параметры, связанные с первым заказом пользователей:
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.

# %% [markdown]
# #### 4.3.1. Анализ влияния дня недели первой покупки на вероятность повторного заказа

# %%
# Добавим столбец с названием дня недели
user_profile['day_of_week'] = user_profile['first_date'].dt.weekday + 1

# %%
# Сгруппируем данные по новому столбцу и вычислим нужные показатели
# делаем группировку по столбцу с днем недели
result=user_profile.groupby('day_of_week').agg(
    user_count = ('user_id', 'count'), # количество пользователей
    repurchase_rate = ('is_two', 'mean'), # доля клиентов совершивших два и более заказов
).reset_index()
result['repurchase_rate']=result['repurchase_rate'].round(3)
display(result)
# Out:
#    day_of_week  user_count  repurchase_rate
# 0            1        2809            0.616
# 1            2        3009            0.599
# 2            3        2958            0.610
# 3            4        3023            0.583
# 4            5        3158            0.585
# 5            6        3118            0.603
# 6            7        2637            0.579

# %%
# Построим столбчатую диаграмму по распределению количества пользователей по дням недели
# Построение столбчатой диаграммы
plt.figure(figsize=(10, 5))  # Размер фигуры
plt.bar(result['day_of_week'], result['user_count'])
plt.title('Количество пользователей по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество пользователей')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# Построим столбчатую диаграмму по доле пользователей с повторными заказами
# Построение столбчатой диаграммы
plt.figure(figsize=(10, 5))  # Размер фигуры
plt.bar(result['day_of_week'], result['repurchase_rate'])
plt.title('Доля пользователей с повторными заказами по дням недели')
plt.xlabel('День недели')
plt.ylabel('Доля пользователей')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# - Увеличенное количество пользоваталей во вторник (после низкого понедельника) и далее постепенный рост с максимумом в субботу и резкое снижение в воскресенье.
# - Доля ведет себя по-другому. Самая высокая доля в понедльник, затем среда и суббота. Самая низкая в воскресенье, четверг и субботу.
#     - Колебания доли при этом незначительные от 0.58 до 0.62.
#
# Нельзя сделать однозначного вывода о влиянии дня недели, в которую совершена первая покупка, на вероятность возврата клиента.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Когда планируют досуг, но возвращаемость остаётся примерно одинаковой — это говорит о том, что день недели первой покупки не влияет на лояльность, а повторное использование сервиса определяется скорее качеством опыта и интересом к мероприятиям

# %% [markdown]
# #### 4.3.2. Влияние среднего интервала между заказами на удержание клиентов.

# %% [markdown]
# Исследуем зависимость интервала между заказами на число заказов.

# %%
user_profile.plot(kind='scatter',
          x='avg_days',
          y='total_orders',
          alpha=0.5,
          color='gold',
          edgecolor='black',
          figsize=(12, 4),        
          title='Анализ числа заказов и среднего интервала между заказами')
# Out:
# <AxesSubplot:title={'center':'Анализ числа заказов и среднего интервала между заказами'}, xlabel='avg_days', ylabel='total_orders'>

# %% [markdown]
# На диаграмме видна нелинейная отрицательная зависимость переменных. То есть при росте кол-ва дней между заказами нелинейно падает кол-во заказов.

# %%
# Рассчитаем среднее время между заказами для групп пользователей
filtered_data=user_profile[user_profile['is_two']==1]
result=filtered_data.groupby('is_five').agg(
    user_count = ('user_id', 'count'), # количество пользователей
    avg_days = ('avg_days', 'mean'), # средний интервал между заказами
    avg_orders = ('total_orders', 'mean'), # средний интервал между заказами
).reset_index()
#result['avg_days']=result['avg_days']
print('\nСреднее время между заказами для сегмента от 2 до 4 заказов (0) и для 5 и более заказов (1)')
display(result)
# Out:
# Среднее время между заказами для сегмента от 2 до 4 заказов (0) и для 5 и более заказов (1)
#    is_five  user_count   avg_days  avg_orders
# 0        0        7144   21.34298    2.696389
# 1        1        5208  11.179152   10.643241

# %% [markdown]
# В сегменте от 2 до 4х заказов средний интервал между заказами в 2 раза больше, чем в сегменте 5 и более заказов.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# <b>Отлично ✅:</b> По расчетам все верно!
#
# </div>

# %% [markdown]
# ### 4.4. Корреляционный анализ количества покупок и признаков пользователя.

# %% [markdown]
# #### 4.4.1: Корреляционный анализ
# Рассчитаем коэффициент корреляции phi_k между признаками профиля пользователя и числом заказов ( total_orders ).

# %%
user_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20712 entries, 0 to 21831
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           20712 non-null  object
#  1   first_date        20712 non-null  datetime64[ns]
#  2   last_date         20712 non-null  datetime64[ns]
#  3   first_device      20712 non-null  object
#  4   first_region      20712 non-null  object
#  5   first_service     20712 non-null  object
#  6   first_event_type  20712 non-null  object
#  7   total_orders      20712 non-null  int64
#  8   avg_revenue       20712 non-null  float32
#  9   avg_tickets       20712 non-null  float64
#  10  avg_days          12381 non-null  Float64
#  11  is_two            20712 non-null  int64
#  12  is_five           20712 non-null  int64
#  13  ticket_interval   19375 non-null  category
#  14  day_of_week       20712 non-null  int64
# ...

# %%
# Вычисляем корреляционную матрицу с использованием phi_k
correlation_matrix = user_profile[['first_device', 'first_region', 'first_service', 'first_event_type', 'avg_revenue',
                         'avg_tickets', 'avg_days', 'first_date', 'total_orders', 'day_of_week']].phik_matrix(interval_cols=['avg_revenue', 'avg_tickets', 'avg_days', 'total_orders'])

# Выводим результат в виде тепловой карты
print('Корреляционная матрица с коэффициентом phi_k для переменной total_orders')

plt.figure(figsize=(2, 6))

# Сохраняем матрицу корреляции признака rating с другими признаками заведений
data_heatmap = correlation_matrix.loc[correlation_matrix.index != 'total_orders'][['total_orders']].sort_values(by='total_orders', ascending=False)
sns.heatmap(data_heatmap,
            annot=True, # Отображаем численные значения в ячейках карты
            fmt='.2f', # Форматируем значения корреляции: два знака после точки
            cmap='coolwarm', # Устанавливаем цветовую гамму от красного (макс. значение) к синему
            linewidths=0.5, # Форматируем линию между ячейками карты
            cbar=False # Отключаем цветовую шкалу
           )

# Добавляем заголовок и подпись по оси Х
plt.title('Тепловая карта коэффициента phi_k \n для данных total_orders')
plt.xlabel('Кол-во заказов')

# Выводим график
plt.show()
# Out:
# Корреляционная матрица с коэффициентом phi_k для переменной total_orders

# %% [markdown]
# Тепловая карта подтверждает ранее сделанные выводы о зависимостях данных.

# %% [markdown]
# Проверим изменятся ли показатели при использовании для корреляции интервалов с количеством заказов:

# %%
# Добавим столбец с интервалами по количеству заказов
# Определяем интервалы
bins = [0, 1, 4, float('inf')]
labels = ['<=1 заказ', '<= 4 заказа', '>= 5 заказов']

# Разбиваем столбец на интервалы
user_profile['orders_interval'] = pd.cut(user_profile['total_orders'], bins=bins, labels=labels)

# %% [markdown]
# Добавим в тепловую карту интервалы по заказам и количеству билетов:

# %%
# Вычисляем корреляционную матрицу с использованием phi_k
correlation_matrix = user_profile[['first_device', 'first_region', 'first_service', 'first_event_type', 'avg_revenue',
                         'avg_tickets', 'avg_days', 'first_date', 'day_of_week', 'orders_interval', 'ticket_interval']].phik_matrix(interval_cols=['avg_revenue', 'avg_tickets', 'avg_days'])

# Выводим результат в виде тепловой карты
print('Корреляционная матрица с коэффициентом phi_k для переменной orders_interval')

plt.figure(figsize=(2, 6))

# Сохраняем матрицу корреляции признака rating с другими признаками заведений
data_heatmap = correlation_matrix.loc[correlation_matrix.index != 'orders_interval'][['orders_interval']].sort_values(by='orders_interval', ascending=False)
sns.heatmap(data_heatmap,
            annot=True, # Отображаем численные значения в ячейках карты
            fmt='.2f', # Форматируем значения корреляции: два знака после точки
            cmap='coolwarm', # Устанавливаем цветовую гамму от красного (макс. значение) к синему
            linewidths=0.5, # Форматируем линию между ячейками карты
            cbar=False # Отключаем цветовую шкалу
           )

# Добавляем заголовок и подпись по оси Х
plt.title('Тепловая карта коэффициента phi_k \n для данных orders_interval')
plt.xlabel('Интервальное кол-во заказов')

# Выводим график
plt.show()
# Out:
# Корреляционная матрица с коэффициентом phi_k для переменной orders_interval

# %% [markdown]
# При использовании интервалов с количеством заказов корреляция по основным показателям - среднее количество дней между заказами, среднее число билетов в заказе, средняя выручка немного подросла.

# %% [markdown]
# Тепловая карта подтверждает зависимость в поведении клиентов от срока с последнего заказа, чредних показателей в заказе по выручке и числу билетов.
# Зависимости от сервиса, регоиона , типа мероприятия, дня недели первой покупки и тп нет.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С этим заданием тоже справились!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Не забываем написать пояснение к шагу.
#
#
# * Мы не получили для `orders_count` нулевых корреляций, но ради эксперимента все же можно было бы проверить, насколько сильно поменяются оценки, если сбалансировать разбиение на интервалы.
#
#
#
#
# * В выводах Было бы неплохо сделать более явный акцент на том, что поведение клиентов во времени и количество билетов важнее для объяснения повторных покупок, чем их демография или первый выбор сервиса.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавила вывод.</div>

# %% [markdown]
# ## 5. Общие выводы и рекомендации.
# - В ходе исследования проанализировали данные о 290 тыс заказах с сервиса Яндекс-афиша. Данные включали информацию по количеству билетов и сумме заказов, типу мероприятия, региону и городу за период июнь - октябрь 2024г.
# - Часть данных была в валюте Казахстана - было выполнено приведение к единой валюте рублям для корректного анализа по выручке.
# - После проверки на дубликаты и выбросы было отфильтровано 3432 строки, что составляет 1.18% данных.
#
# ### Основные результаты
# Был собран профиль пользователей с информацией о 21тыс пользователей с данными о первом заказе пользователя, общим количеством заказов, средней выручкой по заказу и средним интервалом между заказами по каждому пользователю.
# - Общее число пользователей в выборке: 20712
# - Средняя выручка с одного заказа: 546.0
# - Доля пользователей, совершивших 2 и более заказа: 0.6
# - Доля пользователей, совершивших 5 и более заказов: 0.25
#
# Возврат клиентов:
# - На возврат клиентов не влияют демография или первый выбор сервиса, тип первого мероприятия.
# - Высокая доля 0.72 повторых заказов у клиентов со средним числом билетов в заказе от 2х до 3х (не включая 2), сегмент с количеством билетов в заказе до 5 включительно так же имеет повышенную долю возвратов  0.62. У клиентов с 2 билетами в заказе и ниже доля воторных заказов напротив снижена 0.48.
# - У клиентов с 5 заказами и выше средняя выручка в каждом заказе более приближена к средней выручке по всей выборке ~500 руб. Эти клиенты более стабильные по выручке.
# - Чем выше интервал между покупками чем меньше вероятность возвращения клиента.
#
#
# ### Выводы
# - На возврат клиентов значительней влияют показатели по времени с последней покупки, количеству билетов и среднему чеку, чем их демография или первый выбор сервиса.
# - Самая лояльная группа клиентов 5+ заказов является самой стабильной по выручке и достаточно многочисленной - 25%.
# - Высокая вероятность возврата у клиентов с 2-3 билетами в заказе. В этой группе 72% клиентов с повторным заказом.
#
#
# ### Рекомендации
# - В целом можно сконцентрировать маркетинговые усилия на клиентах с 2-3 билетами в заказе - это к тому же самая многочисленная группа в текущей выборке. Необходимо проверить гипотезу, что это пара или семья с 1 ребенком и сконцентрировать маркетинговую коммуникацию на этом сегменте. Мотивировать этих клиентов на регулярность покупок (например скидка, при регулярном посещении и тп).
# - Нужно удерживать лояльность клиентов с 5 и выше заказами - как самой стабильной и лояльной группы. Программа лояльности, предложения с закрытыми или эксклюзивными показами с приоритетной продажей билетов или предбронирование билетов. Так же подумать о увеличении среднего чека в этой группе.
# - Сделать дополнительный анализ и сегментацию клиентов с 1 заказом на 1-2 билета. Постараться перевести их в группу с 2+ заказами. Предлгагать скидку на второй заказ в течении месяца и т.п.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Рекоменадции сейчас немного общие. Понятно, что нужно работать над этим. Можно и без анализа предложить "Дополнительно в первые 10 дней после совершения заказа можно присылать напоминание всем пользователям, возможно с перонализированным предложением на основании первого заказа.."    Всё же рекомендую более таргетно, на основе полученных данных предлагать рекомендации

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Cкорректировала рекомендации.</div>
